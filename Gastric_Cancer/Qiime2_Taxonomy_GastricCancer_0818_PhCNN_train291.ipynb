# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
# !gdown --id '1MaKUC_AsqQmQQLhwqwmw3dC_u5GBoMYr' --output level-6-train.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MaKUC_AsqQmQQLhwqwmw3dC_u5GBoMYr
# To: /content/level-6-train.csv
# 100% 550k/550k [00:00<00:00, 80.4MB/s]

# %%
train = pd.read_csv("level-6-train.csv")
train.head()
# Out:
#         index  ...      Cancer
# 0  SRR3991006  ...  non-cancer
# 1  SRR3991007  ...      cancer
# 2  SRR3991008  ...  non-cancer
# 3  SRR3991009  ...  non-cancer
# 4  SRR3991010  ...      cancer
#
# [5 rows x 710 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Columns: 710 entries, index to Cancer
# dtypes: float64(295), int64(413), object(2)
# memory usage: 1.6+ MB

# %%
not_select = ["index", "Cancer", "Merged"]
train_select = train.drop(not_select,axis=1)
train_select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Columns: 707 entries, Archaea;Crenarchaeota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus_Nitrocosmicus to Unassigned;__;__;__;__;__
# dtypes: float64(295), int64(412)
# memory usage: 1.6 MB

# %%
CAT_COL = ["index", "Cancer"]

NUM_COL=[]
for i in range(len(train.columns)):
  NUM_COL.append(train.columns[i])
NUM_COL.remove('index')
NUM_COL.remove('Cancer')

cat_col = []
num_col = []
for col in train_select:
  if col in CAT_COL:
    cat_col.append(col)
  elif col in NUM_COL:
    num_col.append(col)

for col in cat_col:
  if train_select[col].dtype != "O":
    # print(col)
    train_select[col] = train_select[col].astype(str)

df_cat_select = train_select.loc[:,cat_col] # take all the categorical columns
#df_cat_select = pd.get_dummies(df_cat_select) # one hot encoding

df_num_select = train_select.loc[:,num_col] # take all the numerical columns
df_final_select_train = pd.concat([df_cat_select, df_num_select], axis=1) # concat categorical/numerical data

# %%
df_final_select_train.head()
# Out:
#    Archaea;Crenarchaeota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus_Nitrocosmicus  ...  Unassigned;__;__;__;__;__
# 0                                                  0                                                    ...                        0.0
# 1                                                  0                                                    ...                        0.0
# 2                                                  0                                                    ...                        0.0
# 3                                                  0                                                    ...                        0.0
# 4                                                  0                                                    ...                        0.0
#
# [5 rows x 707 columns]

# %%
# !gdown --id '1kX-7qSFWTQcUaypeVaRDUOlItqW8-KQ1' --output level-6-test.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1kX-7qSFWTQcUaypeVaRDUOlItqW8-KQ1
# To: /content/level-6-test.csv
# 100% 288k/288k [00:00<00:00, 41.2MB/s]

# %%
test = pd.read_csv("level-6-test.csv")
test.head()
# Out:
#         index  ...      Cancer
# 0  SRR8902009  ...  non-cancer
# 1  SRR8902010  ...  non-cancer
# 2  SRR8902011  ...  non-cancer
# 3  SRR8902012  ...  non-cancer
# 4  SRR8902013  ...  non-cancer
#
# [5 rows x 710 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Columns: 710 entries, index to Cancer
# dtypes: float64(587), int64(121), object(2)
# memory usage: 682.4+ KB

# %%
not_select = ["index", "Cancer", "Merged"]
test_select = test.drop(not_select,axis=1)
test_select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Columns: 707 entries, Archaea;Crenarchaeota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus_Nitrocosmicus to Unassigned;__;__;__;__;__
# dtypes: float64(587), int64(120)
# memory usage: 679.5 KB

# %%
cat_col = []
num_col = []
for col in test_select:
  if col in CAT_COL:
    cat_col.append(col)
  elif col in NUM_COL:
    num_col.append(col)

for col in cat_col:
  if test_select[col].dtype != "O":
    # print(col)
    test_select[col] = test_select[col].astype(str)

df_cat_select = test_select.loc[:,cat_col] # take all the categorical columns
#df_cat_select = pd.get_dummies(df_cat_select) # one hot encoding

df_num_select = test_select.loc[:,num_col] # take all the numerical columns
df_final_select_test = pd.concat([df_cat_select, df_num_select], axis=1) # concat categorical/numerical data

# %%
df_final_select_test.head()
# Out:
#    Archaea;Crenarchaeota;Nitrososphaeria;Nitrososphaerales;Nitrososphaeraceae;Candidatus_Nitrocosmicus  ...  Unassigned;__;__;__;__;__
# 0                                                0.0                                                    ...                   0.001277
# 1                                                0.0                                                    ...                   0.000338
# 2                                                0.0                                                    ...                   0.000416
# 3                                                0.0                                                    ...                   0.000840
# 4                                                0.0                                                    ...                   0.000719
#
# [5 rows x 707 columns]

# %% [markdown]
# #DNN

# %%
import os
import numpy as np
import keras as K
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
os.environ['TF_CPP_MIN_LOG_LEVEL']= '2'

# %%
target_var = 'Cancer'
features = list(df_final_select_train.columns)
# 目標變量的類別
Class = train[target_var].unique()
# 目標變量的類別字典
Class_dict = dict(zip(Class, range(len(Class))))
# 增加一列target, 將目標變量進行編碼
train['target'] = train[target_var].apply(lambda x: Class_dict[x])
# 對目標變量進行0-1編碼(One-hot Encoding)
lb = LabelBinarizer()
lb.fit(list(Class_dict.values()))
transformed_labels = lb.transform(train['target'])
label2 = np.zeros((291,1))

for i in range(len(transformed_labels)):
  if transformed_labels[i][0] == 0:
    label2[i][0] = np.int(1)
  elif transformed_labels[i][0] == 1:
    label2[i][0] = np.int(0)

transformed_labels = np.concatenate((transformed_labels, label2),axis=1)

y_bin_labels_train = []  # 對多分類進行0-1編碼的變量
for i in range(transformed_labels.shape[1]):
    y_bin_labels_train.append( 'y' + str(i))
    train['y' + str(i)] = transformed_labels[:, i]

# %%
target_var = 'Cancer'
features = list(df_final_select_test.columns)
# 目標變量的類別
Class = test[target_var].unique()
# 目標變量的類別字典
Class_dict = dict(zip(Class, range(len(Class))))
# 增加一列target, 將目標變量進行編碼
test['target'] = test[target_var].apply(lambda x: Class_dict[x])
# 對目標變量進行0-1編碼(One-hot Encoding)
lb = LabelBinarizer()
lb.fit(list(Class_dict.values()))
transformed_labels = []
transformed_labels = lb.transform(test['target'])
label3 = np.zeros((123,1))

for i in range(len(transformed_labels)):
  if transformed_labels[i][0] == 0:
    label3[i][0] = np.int(1)
  elif transformed_labels[i][0] == 1:
    label3[i][0] = np.int(0)

transformed_labels = np.concatenate((transformed_labels, label3),axis=1)
y_bin_labels_test = []  # 對多分類進行0-1編碼的變量
for i in range(transformed_labels.shape[1]):
    y_bin_labels_test.append( 'y' + str(i))
    test['y' + str(i)] = transformed_labels[:, i]

# %%
# 將數據集分為訓練集和測試集
train_x = df_final_select_train[features]
test_x = df_final_select_test[features]
train_y = train[y_bin_labels_train]
test_y = test[y_bin_labels_test]

# %%
np.random.seed(5)
# model
init = K.initializers.glorot_uniform(seed=1)
model = K.models.Sequential()
model.add(K.layers.Dense(units=200, input_dim=707, kernel_initializer=init, activation='relu'))
# model.add(K.layers.Dense(units=2048, kernel_initializer=init, activation= 'relu'))
# model.add(K.layers.Dense(units=1024, kernel_initializer=init, activation= 'relu'))
model.add(K.layers.Dense(units=2, kernel_initializer=init, activation='relu'))

# %%
# 訓練模型
opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='categorical_crossentropy',
        metrics=['accuracy'])

h = model.fit(train_x, train_y, epochs=50, batch_size=4,
      validation_data=(test_x, test_y))
# Out:
# Epoch 1/50
# 73/73 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.5189 - val_loss: nan - val_accuracy: 0.4797
# Epoch 2/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.9637 - accuracy: 0.6254 - val_loss: 0.7412 - val_accuracy: 0.4797
# Epoch 3/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.7384 - accuracy: 0.7010 - val_loss: 1.0035 - val_accuracy: 0.4797
# Epoch 4/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.6804 - val_loss: 1.0226 - val_accuracy: 0.4959
# Epoch 5/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7113 - val_loss: 1.0756 - val_accuracy: 0.4878
# Epoch 6/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7491 - val_loss: 1.0906 - val_accuracy: 0.4797
# Epoch 7/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5406 - accuracy: 0.7010 - val_loss: 1.2287 - val_accuracy: 0.4878
# Epoch 8/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7732 - val_loss: 1.0587 - val_accuracy: 0.5041
# Epoch 9/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7629 - val_loss: 1.4543 - val_accuracy: 0.4959
# Epoch 10/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7766 - val_loss: 1.2266 - val_accuracy: 0.4878
# Epoch 11/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.7663 - val_loss: nan - val_accuracy: 0.4878
# Epoch 12/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7766 - val_loss: nan - val_accuracy: 0.4959
# Epoch 13/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7732 - val_loss: nan - val_accuracy: 0.5041
# Epoch 14/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7663 - val_loss: nan - val_accuracy: 0.4797
# Epoch 15/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7285 - val_loss: 1.3769 - val_accuracy: 0.4797
# Epoch 16/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7629 - val_loss: 0.7618 - val_accuracy: 0.4959
# Epoch 17/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7801 - val_loss: 1.1808 - val_accuracy: 0.5122
# Epoch 18/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8007 - val_loss: 1.4953 - val_accuracy: 0.5041
# Epoch 19/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7904 - val_loss: 1.3690 - val_accuracy: 0.5041
# Epoch 20/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7491 - val_loss: 1.1089 - val_accuracy: 0.4878
# Epoch 21/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7698 - val_loss: 1.2017 - val_accuracy: 0.4878
# Epoch 22/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7938 - val_loss: 1.3666 - val_accuracy: 0.4878
# Epoch 23/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7904 - val_loss: 1.3691 - val_accuracy: 0.5122
# Epoch 24/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8126 - accuracy: 0.7560 - val_loss: 0.7211 - val_accuracy: 0.5203
# Epoch 25/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5166 - accuracy: 0.7663 - val_loss: 0.7025 - val_accuracy: 0.5122
# Epoch 26/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.4917 - accuracy: 0.7732 - val_loss: 0.7272 - val_accuracy: 0.5203
# Epoch 27/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.4679 - accuracy: 0.7766 - val_loss: 0.7834 - val_accuracy: 0.5203
# Epoch 28/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.4515 - accuracy: 0.7801 - val_loss: 0.8338 - val_accuracy: 0.5203
# Epoch 29/50
# 73/73 [==============================] - 0s 3ms/step - loss: 0.4362 - accuracy: 0.7869 - val_loss: 0.8839 - val_accuracy: 0.5203
# Epoch 30/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7973 - val_loss: 0.9490 - val_accuracy: 0.5285
# Epoch 31/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8110 - val_loss: 0.9390 - val_accuracy: 0.5122
# Epoch 32/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8041 - val_loss: 0.9792 - val_accuracy: 0.5122
# Epoch 33/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8076 - val_loss: 1.1756 - val_accuracy: 0.4959
# Epoch 34/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8213 - val_loss: 1.1433 - val_accuracy: 0.4959
# Epoch 35/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8247 - val_loss: 1.2126 - val_accuracy: 0.4959
# Epoch 36/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8144 - val_loss: 1.3340 - val_accuracy: 0.5041
# Epoch 37/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8213 - val_loss: 1.8223 - val_accuracy: 0.6016
# Epoch 38/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7423 - val_loss: 0.9664 - val_accuracy: 0.4715
# Epoch 39/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7457 - val_loss: 1.0267 - val_accuracy: 0.4878
# Epoch 40/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8385 - val_loss: 1.5532 - val_accuracy: 0.4797
# Epoch 41/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8522 - val_loss: 1.8526 - val_accuracy: 0.4878
# Epoch 42/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8385 - val_loss: nan - val_accuracy: 0.5285
# Epoch 43/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8076 - val_loss: nan - val_accuracy: 0.6260
# Epoch 44/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8110 - val_loss: nan - val_accuracy: 0.5203
# Epoch 45/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8179 - val_loss: nan - val_accuracy: 0.4797
# Epoch 46/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8144 - val_loss: nan - val_accuracy: 0.6016
# Epoch 47/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8213 - val_loss: nan - val_accuracy: 0.5528
# Epoch 48/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8144 - val_loss: nan - val_accuracy: 0.5285
# Epoch 49/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.8041 - val_loss: nan - val_accuracy: 0.5203
# Epoch 50/50
# 73/73 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.7904 - val_loss: nan - val_accuracy: 0.5528

# %%
# summarize history for accuracy
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #PH-CNN
# ##reference:
# ###https://github.com/dfioravanti/phylogenetic-cnn
# ###https://www.tensorflow.org/tutorials/images/cnn

# %%
import os
from tensorflow.keras import datasets, layers, models

# %% [markdown]
# ##Import coordinate data

# %%
# !gdown --id '1E97dcVIaeaRQB7O0MpENzg33AwLOdM7y' --output ordinate_train.csv
C_train = pd.read_csv("ordinate_train.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E97dcVIaeaRQB7O0MpENzg33AwLOdM7y
# To: /content/ordinate_train.csv
# 100% 454k/454k [00:00<00:00, 64.8MB/s]

# %%
C_train.head()
# Out:
#         index         1         2  ...           129           130  Merged
# 0  SRR3991006 -1.063221 -0.000890  ... -4.370000e-11 -2.110000e-10    2634
# 1  SRR3991007 -1.121573  0.018697  ... -3.500000e-11 -1.350000e-10    1839
# 2  SRR3991008 -1.112753 -0.073487  ...  9.090000e-11  3.730000e-10    5166
# 3  SRR3991009 -0.957607  0.032730  ... -3.200000e-11 -3.290000e-10    5558
# 4  SRR3991010 -1.189938 -0.064010  ...  5.730000e-11  2.250000e-10   11350
#
# [5 rows x 132 columns]

# %%
not_select=['index', 'Merged']
C_final_train = C_train.drop(not_select,axis=1)
C_final_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Columns: 130 entries, 1 to 130
# dtypes: float64(130)
# memory usage: 295.7 KB

# %%
C_final_train.head()
# Out:
#           1         2         3  ...           128           129           130
# 0 -1.063221 -0.000890 -0.056303  ...  1.500000e-08 -4.370000e-11 -2.110000e-10
# 1 -1.121573  0.018697  0.066428  ...  9.260000e-09 -3.500000e-11 -1.350000e-10
# 2 -1.112753 -0.073487 -0.435167  ... -2.750000e-08  9.090000e-11  3.730000e-10
# 3 -0.957607  0.032730 -0.017498  ...  2.010000e-08 -3.200000e-11 -3.290000e-10
# 4 -1.189938 -0.064010 -0.270061  ... -1.750000e-08  5.730000e-11  2.250000e-10
#
# [5 rows x 130 columns]

# %%
# !gdown --id '1myMxkf61hmEYglDUO9K_Qm9NI2Utsc0J' --output ordinate_test.csv
C_test = pd.read_csv("ordinate_test.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1myMxkf61hmEYglDUO9K_Qm9NI2Utsc0J
# To: /content/ordinate_test.csv
# 100% 192k/192k [00:00<00:00, 68.9MB/s]

# %%
C_test.head()
# Out:
#         index         1         2  ...           129           130  Merged
# 0  SRR8902009  3.186100  1.042724  ...  1.230000e-08 -8.500000e-09   43058
# 1  SRR8902010  3.008845  0.703913  ... -4.950000e-10  5.760000e-10   53224
# 2  SRR8902011  2.527694  0.111656  ...  8.940000e-10  1.330000e-09   38463
# 3  SRR8902012  2.233100 -0.299058  ...  6.380000e-09 -1.310000e-09   32140
# 4  SRR8902013  2.531365  0.049526  ...  1.830000e-06  1.280000e-07   56985
#
# [5 rows x 132 columns]

# %%
not_select=['index', 'Merged']
C_final_test = C_test.drop(not_select,axis=1)
C_final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Columns: 130 entries, 1 to 130
# dtypes: float64(130)
# memory usage: 125.0 KB

# %%
C_final_test.head()
# Out:
#           1         2         3  ...           128           129           130
# 0  3.186100  1.042724 -0.174329  ...  1.120000e-06  1.230000e-08 -8.500000e-09
# 1  3.008845  0.703913 -0.111238  ... -9.560000e-08 -4.950000e-10  5.760000e-10
# 2  2.527694  0.111656 -0.013524  ... -1.120000e-07  8.940000e-10  1.330000e-09
# 3  2.233100 -0.299058  0.049786  ...  1.950000e-07  6.380000e-09 -1.310000e-09
# 4  2.531365  0.049526 -0.000710  ...  1.830000e-06  1.830000e-06  1.280000e-07
#
# [5 rows x 130 columns]

# %%
X_final_train = pd.concat([df_final_select_train, C_final_train], axis=1)
X_final_test = pd.concat([df_final_select_test, C_final_test], axis=1)
print(X_final_train.shape)
print(X_final_test.shape)
# Out:
# (291, 837)
# (123, 837)

# %%
target_var = 'Cancer'
features = list(X_final_train.columns)
# 目標變量的類別
Class = train[target_var].unique()
# 目標變量的類別字典
Class_dict = dict(zip(Class, range(len(Class))))
# 增加一列target, 將目標變量進行編碼
train['target'] = train[target_var].apply(lambda x: Class_dict[x])
# 對目標變量進行0-1編碼(One-hot Encoding)
lb = LabelBinarizer()
lb.fit(list(Class_dict.values()))
transformed_labels = lb.transform(train['target'])
label2 = np.zeros((291,1))

for i in range(len(transformed_labels)):
  if transformed_labels[i][0] == 0:
    label2[i][0] = np.int(1)
  elif transformed_labels[i][0] == 1:
    label2[i][0] = np.int(0)

transformed_labels = np.concatenate((transformed_labels, label2),axis=1)
y_bin_labels_train = []  # 對多分類進行0-1編碼的變量
for i in range(transformed_labels.shape[1]):
    y_bin_labels_train.append( 'y' + str(i))
    train['y' + str(i)] = transformed_labels[:, i]

# %%
target_var = 'Cancer'
features = list(X_final_test.columns)
# 目標變量的類別
Class = test[target_var].unique()
# 目標變量的類別字典
Class_dict = dict(zip(Class, range(len(Class))))
# 增加一列target, 將目標變量進行編碼
test['target'] = test[target_var].apply(lambda x: Class_dict[x])
# 對目標變量進行0-1編碼(One-hot Encoding)
lb = LabelBinarizer()
lb.fit(list(Class_dict.values()))
transformed_labels = lb.transform(test['target'])
label2 = np.zeros((123,1))

for i in range(len(transformed_labels)):
  if transformed_labels[i][0] == 0:
    label2[i][0] = np.int(1)
  elif transformed_labels[i][0] == 1:
    label2[i][0] = np.int(0)

transformed_labels = np.concatenate((transformed_labels, label2),axis=1)
y_bin_labels_test = []  # 對多分類進行0-1編碼的變量
for i in range(transformed_labels.shape[1]):
    y_bin_labels_test.append( 'y' + str(i))
    test['y' + str(i)] = transformed_labels[:, i]

# %%
# 將數據集分為訓練集和測試集
train_x = X_final_train[features]
test_x = X_final_test[features]
train_y = train[y_bin_labels_train]
test_y = test[y_bin_labels_test]

# %%
train_x = train_x.values.reshape(291, 3, 3, 93)
train_x = train_x.reshape(291, 3, 3, 93)
test_x = test_x.values.reshape(123, 3, 3, 93)
test_x = test_x.reshape(123, 3, 3, 93)

# %% [markdown]
# ## Model(Same as paper)

# %%
model = K.models.Sequential()
model.add(K.layers.Conv2D(93, (1, 1), activation='relu', input_shape=train_x.shape[1:]))
model.add(K.layers.Conv2D(50, (1, 1), activation='relu', input_shape=train_x.shape[1:]))
model.add(K.layers.MaxPooling2D((2, 2)))
model.add(K.layers.Flatten())
model.add(K.layers.Dense(64, activation= 'relu'))
model.add(K.layers.Dropout(0.25))
model.add(K.layers.Dense(2,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 3, 3, 93)          8742
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 3, 50)          4700
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 50)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                3264
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 16,836
# Trainable params: 16,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='categorical_crossentropy',
        metrics=['accuracy'])

h2 = model.fit(train_x, train_y, epochs=50, batch_size=4,
      validation_data=(test_x, test_y))
# Out:
# Epoch 1/50
# 73/73 [==============================] - 1s 6ms/step - loss: 0.6927 - accuracy: 0.5395 - val_loss: 0.6930 - val_accuracy: 0.5041
# Epoch 2/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6908 - accuracy: 0.5567 - val_loss: 0.6931 - val_accuracy: 0.5041
# Epoch 3/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6883 - accuracy: 0.5670 - val_loss: 0.6921 - val_accuracy: 0.5285
# Epoch 4/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.5601 - val_loss: 0.6931 - val_accuracy: 0.5122
# Epoch 5/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6790 - accuracy: 0.6014 - val_loss: 0.6936 - val_accuracy: 0.5203
# Epoch 6/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6716 - accuracy: 0.6117 - val_loss: 0.6857 - val_accuracy: 0.5366
# Epoch 7/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6679 - accuracy: 0.5876 - val_loss: 0.6986 - val_accuracy: 0.5285
# Epoch 8/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6649 - accuracy: 0.6048 - val_loss: 0.6997 - val_accuracy: 0.5285
# Epoch 9/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6576 - accuracy: 0.6186 - val_loss: 0.6994 - val_accuracy: 0.5285
# Epoch 10/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6447 - accuracy: 0.6254 - val_loss: 0.6947 - val_accuracy: 0.5285
# Epoch 11/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6423 - accuracy: 0.6357 - val_loss: 0.7179 - val_accuracy: 0.5285
# Epoch 12/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6352 - accuracy: 0.6289 - val_loss: 0.7166 - val_accuracy: 0.5285
# Epoch 13/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6361 - accuracy: 0.6392 - val_loss: 0.7217 - val_accuracy: 0.5285
# Epoch 14/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6245 - accuracy: 0.6598 - val_loss: 0.7003 - val_accuracy: 0.5203
# Epoch 15/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6216 - accuracy: 0.6460 - val_loss: 0.7117 - val_accuracy: 0.5203
# Epoch 16/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6158 - accuracy: 0.6667 - val_loss: 0.6753 - val_accuracy: 0.5610
# Epoch 17/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6092 - accuracy: 0.6701 - val_loss: 0.6957 - val_accuracy: 0.5285
# Epoch 18/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.6701 - val_loss: 0.7376 - val_accuracy: 0.5285
# Epoch 19/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6077 - accuracy: 0.6770 - val_loss: 0.7312 - val_accuracy: 0.5285
# Epoch 20/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5971 - accuracy: 0.6804 - val_loss: 0.7440 - val_accuracy: 0.5285
# Epoch 21/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5893 - accuracy: 0.7079 - val_loss: 0.7464 - val_accuracy: 0.5285
# Epoch 22/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5905 - accuracy: 0.6838 - val_loss: 0.7352 - val_accuracy: 0.5285
# Epoch 23/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5907 - accuracy: 0.6667 - val_loss: 0.7057 - val_accuracy: 0.5447
# Epoch 24/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5732 - accuracy: 0.7079 - val_loss: 0.7173 - val_accuracy: 0.5366
# Epoch 25/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5716 - accuracy: 0.7148 - val_loss: 0.7547 - val_accuracy: 0.5366
# Epoch 26/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5604 - accuracy: 0.7182 - val_loss: 0.7510 - val_accuracy: 0.5366
# Epoch 27/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5467 - accuracy: 0.7216 - val_loss: 0.7062 - val_accuracy: 0.5447
# Epoch 28/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5507 - accuracy: 0.7285 - val_loss: 0.6843 - val_accuracy: 0.5447
# Epoch 29/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5423 - accuracy: 0.7182 - val_loss: 0.7208 - val_accuracy: 0.5447
# Epoch 30/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5357 - accuracy: 0.7182 - val_loss: 0.7594 - val_accuracy: 0.5447
# Epoch 31/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5458 - accuracy: 0.6976 - val_loss: 0.7447 - val_accuracy: 0.5447
# Epoch 32/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5341 - accuracy: 0.7148 - val_loss: 0.7448 - val_accuracy: 0.5447
# Epoch 33/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5183 - accuracy: 0.7320 - val_loss: 0.6700 - val_accuracy: 0.5610
# Epoch 34/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5311 - accuracy: 0.7182 - val_loss: 0.7670 - val_accuracy: 0.5447
# Epoch 35/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7526 - val_loss: 0.6781 - val_accuracy: 0.5528
# Epoch 36/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5292 - accuracy: 0.7182 - val_loss: 0.6937 - val_accuracy: 0.5528
# Epoch 37/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4936 - accuracy: 0.7629 - val_loss: 0.7797 - val_accuracy: 0.5447
# Epoch 38/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7216 - val_loss: 0.6870 - val_accuracy: 0.5528
# Epoch 39/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4880 - accuracy: 0.7560 - val_loss: 0.7091 - val_accuracy: 0.5528
# Epoch 40/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4745 - accuracy: 0.7801 - val_loss: 0.7490 - val_accuracy: 0.5528
# Epoch 41/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4728 - accuracy: 0.7457 - val_loss: 0.7335 - val_accuracy: 0.5528
# Epoch 42/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4721 - accuracy: 0.7388 - val_loss: 0.8602 - val_accuracy: 0.5447
# Epoch 43/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4842 - accuracy: 0.7457 - val_loss: 0.8033 - val_accuracy: 0.5447
# Epoch 44/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4529 - accuracy: 0.7835 - val_loss: 0.8285 - val_accuracy: 0.5447
# Epoch 45/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4684 - accuracy: 0.7457 - val_loss: 0.8018 - val_accuracy: 0.5447
# Epoch 46/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.7766 - val_loss: 0.7182 - val_accuracy: 0.5528
# Epoch 47/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.7869 - val_loss: 0.8240 - val_accuracy: 0.5447
# Epoch 48/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.7904 - val_loss: 0.7823 - val_accuracy: 0.5528
# Epoch 49/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.7904 - val_loss: 0.7775 - val_accuracy: 0.5528
# Epoch 50/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4326 - accuracy: 0.7973 - val_loss: 0.8526 - val_accuracy: 0.5447

# %%
# summarize history for accuracy
plt.plot(h2.history['accuracy'])
plt.plot(h2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ##Model 2
# Activation = relu
# No Dropout

# %%
train_x = train_x.reshape(291, 3, 3, 93)
test_x = test_x.reshape(123, 3, 3, 93)

# %%
model = K.models.Sequential()
model.add(K.layers.Conv2D(93, (3, 3), activation='relu', input_shape=train_x.shape[1:]))
model.add(K.layers.Conv2D(20, (1, 1), activation='relu', input_shape=train_x.shape[1:]))
# model.add(K.layers.MaxPooling2D((2, 2)))
model.add(K.layers.Flatten())
model.add(K.layers.Dense(32, activation= 'relu'))
model.add(K.layers.Dropout(0.15))
model.add(K.layers.Dense(2,activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 2, 2, 93)          34689
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 2, 2, 20)          1880
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 80)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 32)                2592
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 39,227
# Trainable params: 39,227
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0003, decay=1e-3)
model.compile(optimizer=opt, loss='categorical_crossentropy',
        metrics=['accuracy'])

h2 = model.fit(train_x, train_y, epochs=50, batch_size=4,
      validation_data=(test_x, test_y))
# Out:
# Epoch 1/50
# 73/73 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.5223 - val_loss: 6.1174 - val_accuracy: 0.4959
# Epoch 2/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.7630 - accuracy: 0.6323 - val_loss: 6.1208 - val_accuracy: 0.4959
# Epoch 3/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.6357 - val_loss: 2.1993 - val_accuracy: 0.4959
# Epoch 4/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.6220 - val_loss: 1.7312 - val_accuracy: 0.4959
# Epoch 5/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.7017 - accuracy: 0.6770 - val_loss: 0.8790 - val_accuracy: 0.4959
# Epoch 6/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6364 - accuracy: 0.6701 - val_loss: 0.8530 - val_accuracy: 0.5041
# Epoch 7/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6009 - accuracy: 0.6976 - val_loss: 0.8645 - val_accuracy: 0.5041
# Epoch 8/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6376 - accuracy: 0.7045 - val_loss: 0.8977 - val_accuracy: 0.5041
# Epoch 9/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5566 - accuracy: 0.7388 - val_loss: 1.0484 - val_accuracy: 0.5041
# Epoch 10/50
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5565 - accuracy: 0.7354 - val_loss: 1.2221 - val_accuracy: 0.5041
# Epoch 11/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5671 - accuracy: 0.7526 - val_loss: 1.8883 - val_accuracy: 0.5203
# Epoch 12/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5293 - accuracy: 0.7629 - val_loss: 2.3246 - val_accuracy: 0.5366
# Epoch 13/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4825 - accuracy: 0.7869 - val_loss: 5.9544 - val_accuracy: 0.5366
# Epoch 14/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4903 - accuracy: 0.7938 - val_loss: 5.7694 - val_accuracy: 0.5366
# Epoch 15/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4762 - accuracy: 0.8179 - val_loss: 5.5324 - val_accuracy: 0.5366
# Epoch 16/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4921 - accuracy: 0.8282 - val_loss: 5.8527 - val_accuracy: 0.5447
# Epoch 17/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.8419 - val_loss: 5.8441 - val_accuracy: 0.5447
# Epoch 18/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4505 - accuracy: 0.8522 - val_loss: 5.8440 - val_accuracy: 0.5447
# Epoch 19/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3973 - accuracy: 0.8522 - val_loss: 5.8543 - val_accuracy: 0.5447
# Epoch 20/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8488 - val_loss: 5.9496 - val_accuracy: 0.5528
# Epoch 21/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3361 - accuracy: 0.8729 - val_loss: 5.2171 - val_accuracy: 0.5447
# Epoch 22/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3096 - accuracy: 0.8900 - val_loss: 6.0663 - val_accuracy: 0.5447
# Epoch 23/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3276 - accuracy: 0.9107 - val_loss: 5.7080 - val_accuracy: 0.5122
# Epoch 24/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.9175 - val_loss: 5.9248 - val_accuracy: 0.5203
# Epoch 25/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3079 - accuracy: 0.9003 - val_loss: 4.4978 - val_accuracy: 0.5122
# Epoch 26/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9175 - val_loss: 5.3400 - val_accuracy: 0.5041
# Epoch 27/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9313 - val_loss: 5.3311 - val_accuracy: 0.5041
# Epoch 28/50
# 73/73 [==============================] - 0s 4ms/step - loss: 0.1883 - accuracy: 0.9347 - val_loss: 6.3629 - val_accuracy: 0.5041
# Epoch 29/50
# 73/73 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.9313 - val_loss: nan - val_accuracy: 0.5041
# Epoch 30/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9588 - val_loss: nan - val_accuracy: 0.5041
# Epoch 31/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9107 - val_loss: nan - val_accuracy: 0.5203
# Epoch 32/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9347 - val_loss: nan - val_accuracy: 0.5285
# Epoch 33/50
# 73/73 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.9347 - val_loss: nan - val_accuracy: 0.5203
# Epoch 34/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9347 - val_loss: nan - val_accuracy: 0.5203
# Epoch 35/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9450 - val_loss: nan - val_accuracy: 0.5203
# Epoch 36/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9381 - val_loss: nan - val_accuracy: 0.5285
# Epoch 37/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9450 - val_loss: nan - val_accuracy: 0.5203
# Epoch 38/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9244 - val_loss: nan - val_accuracy: 0.5285
# Epoch 39/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9244 - val_loss: nan - val_accuracy: 0.5203
# Epoch 40/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9313 - val_loss: nan - val_accuracy: 0.5285
# Epoch 41/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9175 - val_loss: nan - val_accuracy: 0.5041
# Epoch 42/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9313 - val_loss: nan - val_accuracy: 0.5285
# Epoch 43/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9244 - val_loss: nan - val_accuracy: 0.4959
# Epoch 44/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9210 - val_loss: nan - val_accuracy: 0.5041
# Epoch 45/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9450 - val_loss: nan - val_accuracy: 0.5122
# Epoch 46/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9381 - val_loss: nan - val_accuracy: 0.5122
# Epoch 47/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9347 - val_loss: nan - val_accuracy: 0.5122
# Epoch 48/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9347 - val_loss: nan - val_accuracy: 0.5122
# Epoch 49/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9553 - val_loss: nan - val_accuracy: 0.5122
# Epoch 50/50
# 73/73 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9519 - val_loss: nan - val_accuracy: 0.5122

# %%
# summarize history for accuracy
plt.plot(h2.history['accuracy'])
plt.plot(h2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
